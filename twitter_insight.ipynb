# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df = pd.read_csv(r"C:\Users\junej\Downloads\Tweets.csv")
df.head()
df.drop_duplicates()
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...

# %%
table = pd.pivot_table(data=df, 
                        columns=['negativereason'], 
                        values='tweet_id',
                        aggfunc='count')
table
# Out:
# negativereason  Bad Flight  Can't Tell  Cancelled Flight  \
# tweet_id               580        1190               847
#
# negativereason  Customer Service Issue  Damaged Luggage  \
# tweet_id                          2910               74
#
# negativereason  Flight Attendant Complaints  Flight Booking Problems  \
# tweet_id                                481                      529
#
# negativereason  Late Flight  Lost Luggage  longlines
# tweet_id               1665           724        178

# %%
table1 = pd.pivot_table(data=df,
                        columns=['airline'], 
                        values='airline_sentiment',
                        aggfunc='count')
table1
# Out:
# airline            American  Delta  Southwest  US Airways  United  \
# airline_sentiment      2759   2222       2420        2913    3822
#
# airline            Virgin America
# airline_sentiment             504

# %%
data[(data['airline_sentiment']=='positive')]
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 1      570301130888122368          positive                        0.3486
# 6      570300616901320704          positive                        0.6745
# 8      570299953286942721          positive                        0.6559
# 9      570295459631263746          positive                        1.0000
# 11     570289724453216256          positive                        1.0000
# ...                   ...               ...                           ...
# 14623  569590013278756865          positive                        0.6274
# 14625  569589643487928321          positive                        1.0000
# 14628  569588651925098496          positive                        1.0000
# 14630  569588473050611712          positive                        1.0000
# 14635  569587686496825344          positive                        0.3487
#
#       negativereason  negativereason_confidence         airline  \
# ...

# %%
data[(data['airline_sentiment']=='positive')].describe()
# Out:
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  2.363000e+03                   2363.000000                      330.0
# mean   5.691006e+17                      0.872039                        0.0
# std    8.112476e+14                      0.179478                        0.0
# min    5.676555e+17                      0.335600                        0.0
# 25%    5.684331e+17                      0.677500                        0.0
# 50%    5.691980e+17                      1.000000                        0.0
# 75%    5.698788e+17                      1.000000                        0.0
# max    5.703093e+17                      1.000000                        0.0
#
#        retweet_count
# count    2363.000000
# mean        0.069403
# std         0.659914
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        22.000000

# %%
data[(data['airline']=='United')]
# Out:
#                 tweet_id airline_sentiment  airline_sentiment_confidence  \
# 504   570307876897628160          positive                        1.0000
# 505   570307847281614848          positive                        1.0000
# 506   570307109704900608          negative                        1.0000
# 507   570307026263384064          negative                        1.0000
# 508   570306733010264064          positive                        0.3441
# ...                  ...               ...                           ...
# 4321  567614049425555457          negative                        1.0000
# 4322  567595670463205376          negative                        1.0000
# 4323  567594579310825473          negative                        1.0000
# 4324  567592368451248130          negative                        1.0000
# 4325  567591480085463040          negative                        1.0000
#
#               negativereason  negativereason_confidence airline  \
# ...

# %%
data[(data['airline']=='United')].describe()
# Out:
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  3.822000e+03                   3822.000000                3000.000000
# mean   5.690949e+17                      0.900878                   0.627285
# std    7.515777e+14                      0.162827                   0.324784
# min    5.675915e+17                      0.335000                   0.000000
# 25%    5.684908e+17                      0.693175                   0.357250
# 50%    5.692193e+17                      1.000000                   0.668050
# 75%    5.697103e+17                      1.000000                   1.000000
# max    5.703079e+17                      1.000000                   1.000000
#
#        retweet_count
# count    3822.000000
# mean        0.110152
# std         0.368416
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         7.000000

# %%
df.describe()
# Out:
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  1.464000e+04                  14640.000000               10522.000000
# mean   5.692184e+17                      0.900169                   0.638298
# std    7.791112e+14                      0.162830                   0.330440
# min    5.675883e+17                      0.335000                   0.000000
# 25%    5.685592e+17                      0.692300                   0.360600
# 50%    5.694779e+17                      1.000000                   0.670600
# 75%    5.698905e+17                      1.000000                   1.000000
# max    5.703106e+17                      1.000000                   1.000000
#
#        retweet_count
# count   14640.000000
# mean        0.082650
# std         0.745778
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        44.000000

# %%
is_positive = data['airline_sentiment'].str.contains("positive")
is_negative = data['airline_sentiment'].str.contains("negative")
is_neutral = data['airline_sentiment'].str.contains("neutral")

# %%
positive_tweets = data[is_positive]
positive_tweets.shape
# Out:
# (2363, 15)

# %%
neutral_tweets = data[is_neutral]
neutral_tweets.shape
# Out:
# (3099, 15)

# %%
worst_airline = negative_tweets[['airline','airline_sentiment_confidence','negativereason']]
worst_airline
# Out:
#               airline  airline_sentiment_confidence          negativereason
# 3      Virgin America                        1.0000              Bad Flight
# 4      Virgin America                        1.0000              Can't Tell
# 5      Virgin America                        1.0000              Can't Tell
# 15     Virgin America                        0.6842             Late Flight
# 17     Virgin America                        1.0000              Bad Flight
# ...               ...                           ...                     ...
# 14631        American                        1.0000              Bad Flight
# 14633        American                        1.0000        Cancelled Flight
# 14634        American                        0.6684             Late Flight
# 14636        American                        1.0000  Customer Service Issue
# 14638        American                        1.0000  Customer Service Issue
#
# [9178 rows x 3 columns]

# %%
negative_tweets = data[is_negative]
negative_tweets.shape
# Out:
# (9178, 15)

# %%
cnt_worst_airline = worst_airline.groupby('airline', as_index=False).count()
cnt_worst_airline.sort_values('negativereason', ascending=False)
# Out:
#           airline  airline_sentiment_confidence  negativereason
# 4          United                          2633            2633
# 3      US Airways                          2263            2263
# 0        American                          1960            1960
# 2       Southwest                          1186            1186
# 1           Delta                           955             955
# 5  Virgin America                           181             181

# %%
best_airline = positive_tweets[['airline','airline_sentiment_confidence']]
cnt_best_airline = best_airline.groupby('airline', as_index=False).count()
cnt_best_airline.sort_values('airline_sentiment_confidence', ascending=False)
# Out:
#           airline  airline_sentiment_confidence
# 2       Southwest                           570
# 1           Delta                           544
# 4          United                           492
# 0        American                           336
# 3      US Airways                           269
# 5  Virgin America                           152

# %%
motivation = negative_tweets[['airline','negativereason']]
cnt_bad_flight_motivation = motivation.groupby('negativereason', as_index=False).count()
cnt_bad_flight_motivation.sort_values('negativereason', ascending=False)
# Out:
#                 negativereason  airline
# 9                    longlines      178
# 8                 Lost Luggage      724
# 7                  Late Flight     1665
# 6      Flight Booking Problems      529
# 5  Flight Attendant Complaints      481
# 4              Damaged Luggage       74
# 3       Customer Service Issue     2910
# 2             Cancelled Flight      847
# 1                   Can't Tell     1190
# 0                   Bad Flight      580
